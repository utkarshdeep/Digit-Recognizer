# %%
import cv2 as cv
from matplotlib import pyplot as plt

# %% [markdown]
# ### Load image

# %%
img = cv.imread('9.jpeg', 0)

# %% [markdown]
# ### Display image using OpenCV

# %%
cv.imshow('Image', img)
cv.waitKey(0)
cv.destroyAllWindows()

# %% [markdown]
# ### Display image using Matplotlib

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
img.shape
# Out:
# (514, 729)

# %% [raw]
# To make this image a 28*28 pixel matrix, we first need to crop this img.

# %%
cropped = img[:, 40:554]
cv.imshow("Cropped", cropped)
cv.waitKey(0)
# Out:
# 255

# %%
cropped.shape
# Out:
# (514, 514)

# %% [markdown]
# ### Resize image

# %%
r = 28.0/cropped.shape[1]
dim = (28, int(cropped.shape[0]*r))
resized = cv.resize(cropped, dim, interpolation = cv.INTER_AREA)
plt.imshow(resized, cmap = 'gray', interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
resized.shape
# Out:
# (28, 28)

# %%
from
